# %%
import os
os.getcwd()
os.chdir("C:/Users/hp/Desktop/CovidH")
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Desktop\\CovidH'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import random
import seaborn as sns
import math
import time
from sklearn.linear_model import LinearRegression,BayesianRidge
from sklearn.model_selection import RandomizedSearchCV,train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error,mean_absolute_error
import datetime
import operator
covdd=pd.read_excel("Diuresis_TS.xlsx")
covdd
# Out:
#        people_ID  2020-03-20 00:00:00  2020-03-21 00:00:00  \
# 0              1                  441                544.2
# 1              2                  151                197.2
# 2              3                  416                515.2
# 3              4                  410                506.0
# 4              5                  390                483.0
# 5              6                  389                480.8
# 6              7                  322                401.4
# 7              8                  194                246.8
# 8              9                  310                385.0
# 9             10                  242                303.4
# 10            11                  373                463.6
# 11            12                  192                245.4
# 12            13                  403                497.6
# 13            14                  120                157.0
# 14            15                  382                474.4
# ...

# %%
covdd.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# people_ID              0
# 2020-03-20 00:00:00    0
# 2020-03-21 00:00:00    0
# 2020-03-22 00:00:00    0
# 2020-03-23 00:00:00    0
# 2020-03-24 00:00:00    0
# 2020-03-25 00:00:00    0
# 2020-03-26 00:00:00    0
# dtype: int64

# %%
cod=covdd.keys()

# %%
diuresis_n=covdd.loc[:,cod[7]:cod[-1]]

# %%
dates=diuresis_n.keys()
d_value=[]

# %%
for i in dates:
    d_sum=diuresis_n[i].sum()

# %%
d_value.append(d_sum)

# %%
days=np.array([i for i in range(len(dates))]).reshape(-1,1)
d_value=np.array(d_value).reshape(-1,1)

# %%
days_in_f=4
fut_forcast=np.array([i for i in range(len(dates)+days_in_f)]).reshape(-1,1)
adjusted_dates=fut_forcast[:-4]

# %%
X_train_diuresis_n,X_test_test_diuresis_n,y_train_diuresis_n,y_test_diuresis_n=train_test_split(days,d_value,test_size=0.15,shuffle=False)

# %%
svm_diuresis_n=SVR(shrinking=True,kernel='poly',gamma=0.01,epsilon=1,degree=5,C=0.1)
svm_diuresis_n.fit(X_train_diuresis_n,y_train_diuresis_n)
svm_pred=svm_diuresis_n.predict(fut_forcast)
